# %% [markdown]
# Click on the link below to download the corresponding data:
#
# https://power.larc.nasa.gov/api/temporal/monthly/point?parameters=T2M,PRECTOTCORR&community=SB&longitude=0&latitude=0&start=1981&end=2024&format=CSV
